# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshaySharma10/Machine_Learning_in_public_health_analysis/blob/main/Food_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
food=pd.read_csv(r'/content/drive/MyDrive/Practicum/final_food_items.csv')

# %%
food.head()
# Out:
#          food items  Carbs  Total Fat  Saturated Fat  Protein  Fiber  \
# 0             Apple  25.48      0.364          0.182    0.546  4.368
# 1           Apricot   6.05      0.220          0.000    0.770  1.100
# 2           Avocado   2.70      0.600          0.090    0.600  0.600
# 3            Banana  27.14      0.354          0.118    1.298  3.068
# 4  Black Chokeberry  17.16      0.715          0.000    1.430  4.290
#
#    Cholesterol  Sodium  Sugar  Potassium  Magnesium  Phosphorus  Vitamin C  \
# 0          0.0    0.00  18.20     194.74       9.10       20.02      8.372
# 1          0.0    0.55   4.95     142.45       5.50       12.65      5.500
# 2          0.0    0.00   0.06      75.00       8.70       15.60      3.000
# 3          0.0    1.18  14.16     422.44      31.86       25.96     10.266
# 4          0.0    1.43   4.29    1082.51      41.47       42.90     41.899
#
#    Vitamin A  Calcium   Iron   Zinc  Vitamin E  Vitamin K
# 0      10.92   0.3276  4.004  10.92     0.1820     0.0910
# 1    1059.30   0.4895  1.705   7.15     0.2145     0.1100
# 2       2.10   0.6210  6.300   3.60     0.1800     0.1800
# 3       1.18   0.1180  0.590   5.90     0.3540     0.1770
# 4    1258.40   2.4310  1.287  77.22     2.2880     1.0868

# %%
def calculate_bmr(weight, height, age, gender):
    if gender == 'male':
        bmr = 10 * weight + 6.25 * height - 5 * age + 5
    elif gender == 'female':
        bmr = 10 * weight + 6.25 * height - 5 * age - 161
    else:
        print('Invalid gender')
        return None
    return bmr


def calculate_calories(bmr, activity_level):
    if activity_level == 'sedentary':
        pal = 1.2
    elif activity_level == 'lightly active':
        pal = 1.375
    elif activity_level == 'moderately active':
        pal = 1.55
    elif activity_level == 'very active':
        pal = 1.725
    elif activity_level == 'extra active':
        pal = 1.9
    else:
        print('Invalid activity level')
        return None
    calories = bmr * pal
    return calories


weight = float(input('Enter your weight in kilograms: '))
height = float(input('Enter your height in centimeters: '))
age = int(input('Enter your age: '))
gender = input('Enter your gender (male/female): ')

bmr = calculate_bmr(weight, height, age, gender)
if bmr is not None:
    print(f'Your basal metabolic rate is: {bmr:.2f} calories')

print('Select your activity level:')
print('1. Sedentary (little or no exercise)')
print('2. Lightly active (light exercise/sports 1-3 days/week)')
print('3. Moderately active (moderate exercise/sports 3-5 days/week)')
print('4. Very active (hard exercise/sports 6-7 days/week)')
print('5. Extra active (very hard exercise/sports or physical job)')
level = int(input())

if level == 1:
    activity_level = 'sedentary'
elif level == 2:
    activity_level = 'lightly active'
elif level == 3:
    activity_level = 'moderately active'
elif level == 4:
    activity_level = 'very active'
elif level == 5:
    activity_level = 'extra active'
else:
    print('Invalid activity level')
    activity_level = None

if activity_level is not None:
    calories = calculate_calories(bmr, activity_level)
    if calories is not None:
        print(f'Your daily calorie requirement is: {calories:.2f} calories')
# Out:
# Enter your weight in kilograms: 78
# Enter your height in centimeters: 180
# Enter your age: 19
# Enter your gender (male/female): male
# Your basal metabolic rate is: 1815.00 calories
# Select your activity level:
# 1. Sedentary (little or no exercise)
# 2. Lightly active (light exercise/sports 1-3 days/week)
# 3. Moderately active (moderate exercise/sports 3-5 days/week)
# 4. Very active (hard exercise/sports 6-7 days/week)
# 5. Extra active (very hard exercise/sports or physical job)
# 3
# Your daily calorie requirement is: 2813.25 calories

# %%
diseases_data = pd.read_csv(r'/content/drive/MyDrive/Practicum/diseases.csv')

pre_meal = input("Do you prefer Vegetarian or Non-vegetarian meal?: ")
num_diseases = int(input('How many diseases are you suffering from?'))

user_diseases = []
for i in range(num_diseases):
    disease = input("Enter the name of disease:" + str(i+1) + ": ")
    user_diseases.append(disease)

nutritional_components = []
for disease in user_diseases:
    row = diseases_data.loc[diseases_data['Disease'] == disease]
    nutritional_components.append(list(row.iloc[:, 1:].values[0]))

final_list = nutritional_components[0]
for components in nutritional_components[1:]:
    for i, value in enumerate(components):
        final_list[i] = min(final_list[i], value)

food_items_dict = {}
for i, component_value in enumerate(final_list):
    component_name = diseases_data.columns[i+1]
    food_items = []
    for index, row in food.iterrows():
        food_component_value = row[component_name]
        if abs(float(food_component_value) - float(component_value)) / float(component_value) <= 0.90:
            food_items.append(row['food items'])

    food_items_dict[component_name] = food_items

food_i_list = list(food_items_dict.values())
food_i_list = sum(food_i_list, [])
unique_list = list(set(food_i_list))
print("Final List:", final_list)
print("Unique Food Items:", unique_list)
# Out:
# Do you prefer Vegetarian or Non-vegetarian meal?: Vegetarian
# How many diseases are you suffering from?1
# Enter the name of disease:1: Diabetes
# Final List: [247.5, 73.0, 14.66, 60.0, 30.0, 200.0, 2000.0, 36.0, 2750.0, 365.0, 700.0, 80.0, 800.0, 1100.0, 8.0, 10.0, 15.0, 115.0]
# Unique Food Items: ['Carrot salad', 'Almond Milkshake', 'Flax Seed', 'Buckwheat Groats', 'Peanut', 'Deer Meat', 'Whole Ryes', 'Romaine Lettuce', 'Papaya Juice', 'Macadamia Nuts', 'Hilsa Fish', 'Lentil salad', 'Coffee with cream and sugar', 'Moroccan chickpea salad', 'Water Chestnut', 'Beech Nuts', 'Sardines Fish', 'Ice Cream Bean', 'Spinach', 'Cashew', 'Quail Meat', 'Einkorn Wheat', 'Israeli salad', 'Walnuts', 'Redberries', 'Mango Juice', 'Emmer Wheat', 'Melon and prosciutto salad', 'Ivory Teff', 'paneer sandwich', 'Gazpacho soup', 'Habanero', 'Unsalted Butter', 'Red Pepper', 'Coleslaw Sandwich', 'Candlenut', 'Kabocha Squash', 'Mizuna', 'Pitwaa', 'Italian Wedding Soup', 'Masala chai', 'Elephant garlic', 'French Beans', 'Spelt Farro', 'Basmati Rices', 'Potato salad', 'Broomcorn Sorghum', 'Spiced cider', 'Macaroni salad', 'Horseradish', 'Paratha', 'Galangal', 'Corn and Cheese', 'Bean Sprouts', 'Aloo Toast Sandwich', 'Caesar salad with shrimp', 'Carrots', 'Goat Ghee', 'Frappuccino', 'Watermelon Juice', 'fava beans', 'Brown Bread', 'Poppy Seed', "sheep's milk", 'butternut', 'White Sorghum', 'Strawberry', 'Orange and fennel salad', 'Neeps', 'Tomatoes', 'Buffalo Milk', 'Barley Grits', 'Bread Butter Sandwich', 'beech Nuts', 'Spelt Wheat', 'Limeade', 'Courgette', 'Salmon Nicoise salad', 'Foxtail Millets', 'Mint hot chocolate', 'Grilled vegetable salad', 'Calabrese', 'Black Quinoa', 'Lobster Fish', 'Mushroom', 'Barley Flakes', 'Cochin Chicken', 'Coconut hot chocolate', 'Barnyard Millets', 'Brown Rice', 'PlainYogurt', 'Espresso', 'Beef stew soup', 'Pear', 'Sour Cream', 'Clotted Cream', 'kidney beans', 'Kuka', 'Slushies', 'Lavender latte', 'Heartnut', 'Yardlong Bean', 'Jicama', 'Nectarines', 'King Edward Potato', 'Popcorn', 'Bacon ranch potato salad', 'Cherry', 'Tomato soup', 'Pili Nut', 'White Radish', 'velvet beans', 'Elderberry', "Sheep's Milk", 'Spinach salad', 'High-altitude Quinoa', 'Egg salad', 'Sports Drinks', 'Rose Water Lemonade', 'Steel-cut Oats', 'Garbanzo Beans', 'Bell Peppers', 'Asparagus', 'Asian coleslaw', 'Rye Breads', 'Frisee', 'Jackfruit', 'Whole Grain Quinoa', 'Cold Brew Coffee', 'Beetroot', 'Dasheen', 'Yao Choy', 'Spelt', 'Beef Noodle Soup', 'Almond', 'Rainbow salad', 'Whole grain Sorghum', 'Jam Sandwich', 'Pecans', 'Condensed Milk', 'Grapefruit Juice', 'Green Smoothie', 'Cream of tomato soup', 'Bone broth', 'Lambs Meat', 'Americano', 'Beet and goat cheese salad', 'Chestnut', 'Cheese', 'chocolate Milkshake', 'peanut butter and jelly sandwich', 'pinto\xa0beans', 'Broiler Chicken', 'Squid Seafood', 'Energy Drinks', 'Broccoli cheddar soup', 'Heartnuts', 'Broad Beans', 'Longan Fruit', 'Wild RIce', 'Zucchini', 'Vegetable soup', 'Finger Millet', 'corn and cheese sandwich', 'Pistachios', 'Yellow Onion', 'Pearl Millet', 'Whole Barleys', 'Black Sorghum', 'Coconut', 'Paneer Sandwich', 'White Bread', "Cow's Milk", 'plain yogurt', 'Capsicum', 'navy beans\xa0', 'Kale and quinoa salad', 'Turnips', 'Dent Corn', 'Lentil soup', 'Chai Latte(iced)', 'chicken sandwich', 'French onion soup', 'Green Smoothies', 'Quick Oats', 'Pigeon Meat', 'Borscht Soup', 'Shrimp Seafood', 'Pumpkin Seeds', 'Yerba mate', 'Roma Tomatoes', 'Instant Oatss', 'Chia Seeds', 'Komatsuna', 'White hot chocolate', 'Milkshakes', 'Antipasto salad', 'Watermelon', 'Black Rice', 'Club Sandwich', 'Gooseberries', 'Molokhia', 'Cashew Milkshake', 'Peas', 'mango Lassi', 'Starfruit', 'Avocados', 'Acorn', 'Hemp Seeds', 'Purple Quinoa', 'Butter', 'Eggs', 'Sprouted Grain Bread', 'Beef Meat', 'Rabbits Meat', 'Mongongo Nuts', 'Guinea Fowl Meat', 'Sesame Seed', 'Carrot Juice', 'Lychee', 'Yogurt', 'Rye Flakes', 'Pine Nut', 'Raspberry', 'Gongura', 'Protien Shakes', 'Arnold Palmer', 'Passion Fruit', 'Chickpea salad', 'Arborio Rice', 'Sesame Seeds', 'club sandwich', 'Rock Samphire', 'quinoa seeds', 'Macchiato', 'Peppermint tea', 'Oat Groatss', 'Sweet Potato', 'Purple Barley', 'Mint Lemonande', 'Orange Juice', 'Barley and roasted vegetable salad', 'Peanuts', 'Wax Beans', 'Harrd Red Wheat' ...

# %%
original_calories = 2200
adjusted_list = []
for value in final_list:
    adjusted_value = value * (calories / original_calories)
    adjusted_list.append(round(adjusted_value, 2))
print(adjusted_list)
# Out:
# [316.49, 93.35, 18.75, 76.73, 38.36, 255.75, 2557.5, 46.04, 3516.56, 466.74, 895.12, 102.3, 1023.0, 1406.62, 10.23, 12.79, 19.18, 147.06]

# %%
from termcolor import colored
calorie= pd.read_csv(r'/content/drive/MyDrive/Practicum/Calorie_value.csv')

# %%
if (pre_meal == 'Vegetarian'):
    meal_categories = {
    'Breakfast': ('Breakfast grains', 'Fruits', 'Vegetables', 'Protien', 'Healthy Fats','Breads','Juice','Indian bread','Tea & Coffee'),
    'Lunch': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy'),
    'Snacks': ('Tea & Coffee','Sandwich','Nuts & Seeds','Fruits','Beverages','Juice'),
    'Dinner': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy')
    }

    food_items_by_category = {category: [] for category in meal_categories.values()}

    for food_item in unique_list:

        category = calorie.loc[calorie['food items'] == food_item, 'Category'].values[0]

        for meal_category, categories in meal_categories.items():
            if category in categories:
                food_items_by_category.setdefault(meal_category + ': ' + category, []).append(food_item)

    for meal_category, categories in meal_categories.items():
        print(colored(meal_category.title(), 'blue', attrs=['bold']))
        for category in categories:
            key = meal_category + ': ' + category
            if key in food_items_by_category and food_items_by_category[key]:
                print('   ' + category + ': ' + ', '.join(food_items_by_category[key]))

elif(pre_meal == 'Non-vegetarian'):
    meal_categories = {
    'Breakfast': ('Breakfast grains', 'Fruits', 'Vegetables','Non-veg Protien','Protien', 'Healthy Fats','Breads','Juice','Indian bread','Tea & Coffee'),
    'Lunch': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy','Meat', 'Non-veg Salads','Non-veg Soup'),
    'Snacks': ('Tea & Coffee','Sandwich','Nuts & Seeds','Fruits','Beverages','Juice','Non-veg Sandwich'),
    'Dinner': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy','Meat','Non-veg Salads','Non-veg Soup')
    }

    food_items_by_category = {category: [] for category in meal_categories.values()}

    for food_item in unique_list:

        category = calorie.loc[calorie['food items'] == food_item, 'Category'].values[0]

        for meal_category, categories in meal_categories.items():
            if category in categories:
                food_items_by_category.setdefault(meal_category + ': ' + category, []).append(food_item)

    for meal_category, categories in meal_categories.items():
        print(colored(meal_category.title(), 'blue', attrs=['bold']))
        for category in categories:
            key = meal_category + ': ' + category
            if key in food_items_by_category and food_items_by_category[key]:
                print('   ' + category + ': ' + ', '.join(food_items_by_category[key]))
# Out:
# Breakfast
#    Breakfast grains: Whole Ryes, Basmati Rices, Foxtail Millets, Barnyard Millets, Whole Grain Quinoa, Whole grain Sorghum, Whole Barleys, Instant Oatss, Oat Groatss, White Sorghums, Barley Flakess, Wild Rices, Whole Grain Wheat, Quick Oatss, Sorghum Flakes, Rolled Oatss, Steel-cut Oatss, Sweet Corns, Little Millets, Barley Gritss, Pearl Millets, Brown Rices, Kodo Millets
